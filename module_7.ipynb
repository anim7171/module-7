# %% [markdown]
#  **1. What is the difference between interpreted and compiled languages?**
#
# * **Interpreted**: Code runs line-by-line (e.g., Python). Easier to debug, slower.
# * **Compiled**: Code is translated into machine code before running (e.g., C++). Faster but harder to debu
# 2. What is exception handling in Python?**
#
# * Exception handling allows your code to **respond to errors** without crashing.
# * You use `try`, `except`, `finally`, and `else` to catch and manage errors.
#
#
#
# 3. What is the purpose of the `finally` block in exception handling?**
#
# * The `finally` block **always runs**, whether an exception occurred or not.
# * It’s used to clean up resources, like closing a file or database connection.
#
# 4. What is logging in Python?
#
# * Logging is a way to **track events** that happen when your code runs.
# * It helps with debugging and maintaining your code, especially in large applications.
#
# ---
#
# 5. What is the significance of the `__del__` method in Python?
#
# * It’s called when an object is about to be destroyed.
# * You can use it to **clean up resources**, though relying on it is not always recommended.
#
# 6. What is the difference between `import` and `from ... import` in Python?
#
# * `import module`: Use `module.function()`.
# * `from module import function`: Use `function()` directly.
#
# 7. How can you handle multiple exceptions in Python?
#
# You can catch multiple exceptions using a tuple:
#
#
# try:
#     risky_code()
# except (ValueError, TypeError) as e:
#     print(e)
#
#
#
#
# 8. What is the purpose of the `with` statement when handling files in Python?**
#
# * Automatically **closes the file** after use, even if there’s an error.
#
# ```python
# with open('data.txt') as file:
#     content = file.read()
#
#
# 9. What is the difference between multithreading and multiprocessing?**
#
# * **Multithreading**: Multiple threads share the same memory space. Good for **I/O tasks**.
# * **Multiprocessing**: Each process has its own memory. Better for **CPU-heavy tasks**.
#
# 10. What are the advantages of using logging in a program?**
#
# * Tracks application flow and errors.
# * Helps with **debugging and maintenance**.
# * Can write to files for long-term recordkeeping.
# * Supports different **severity levels** (info, warning, error).
#
# 11. What is memory management in Python?**
#
# * Python manages memory **automatically** using:
#
#   * Reference counting
#   * Garbage collection
#   * Object pooling (e.g., for small integers)
#
# 12. What are the basic steps involved in exception handling in Python?**
#
# 1. `try`: Code that may throw an error.
# 2. `except`: Handle the error.
# 3. `else`: Runs if no error.
# 4. `finally`: Always runs (for cleanup).
#
# 13. Why is memory management important in Python?**
#
# * Prevents memory leaks.
# * Keeps the program efficient.
# * Ensures your app doesn't crash or slow down due to excessive memory use.
#
# 14. What is the role of `try` and `except` in exception handling?**
#
# * `try`: Runs the risky code.
# * `except`: Catches and handles errors if they happen.
#
# 15. How does Python's garbage collection system work?**
#
# * Tracks object references.
# * Deletes objects with **zero references**.
# * Handles **circular references** using a garbage collector.
#
# ---
#
# 16. What is the purpose of the `else` block in exception handling?**
#
# * Runs **only if no exception** occurs in the `try` block.
#
# 17. What are the common logging levels in Python?**
#
# * `DEBUG`: Detailed info (lowest level)
# * `INFO`: General events
# * `WARNING`: Something unexpected
# * `ERROR`: Problem that affects functionality
# * `CRITICAL`: Serious error; program may not continue
#
# ---
#
# 18. What is the difference between `os.fork()` and `multiprocessing` in Python?**
#
# os.fork()`:
#
#   * Unix-only.
#   * Low-level, more control but harder to use.
# * `multiprocessing`:
#
#   * Cross-platform.
#   * Easier to use.
#   * Handles communication and shared memory more cleanly.
#  19  What is the importance of closing a file in Python?
# Closing a file is very important because:
#
#  It frees system resources (e.g., file handles).
#
#  Ensures that all data is properly written to the file when writing.
#
#  Prevents file corruption or data loss.
#
#  Avoids issues when trying to open the same file later.
#
# Best practice: Use the with statement, which automatically closes the file:
#
# python
# Copy
# Edit
# with open("file.txt", "r") as f:
#     content = f.read()
# 🔹 20. What is the difference between file.read() and file.readline() in Python?
# Function	Description
# file.read()	Reads the entire file as a single string.
# file.readline()	Reads just one line at a time from the file.
#
# Example:
#
# python
# Copy
# Edit
# f.read()        # "Hello\nWorld\nBye"
# f.readline()    # "Hello\n"
# Use readline() for reading large files line-by-line to save memory.
#
# 🔹 21. What is the logging module in Python used for?
# The logging module is used to record messages about what’s happening in your program.
#
# You can log:
#
# Errors
#
# Warnings
#
# Information
#
# Logs can go to the console, a file, or both.
#
# Example:
#
# python
# Copy
# Edit
# import logging
# logging.basicConfig(level=logging.INFO)
# logging.info("Program started")
# It’s better than print() because it includes timestamps, levels, and supports writing to files.
#
# 🔹 22. What is the os module in Python used for in file handling?
# The os module lets you interact with the operating system.
#
# In file handling, it helps you:
#
# Create/remove directories: os.mkdir(), os.rmdir()
#
# Rename/delete files: os.rename(), os.remove()
#
# Check if a file exists: os.path.exists()
#
# Example:
#
# python
# Copy
# Edit
# import os
# if os.path.exists("data.txt"):
#     os.remove("data.txt")
# 🔹 23. What are the challenges associated with memory management in Python?
# Reference cycles: Two or more objects refer to each other and never get deleted.
#
# Memory leaks: Keeping unnecessary references to objects prevents them from being garbage collected.
#
# Large data structures: Lists, dictionaries, and arrays can use a lot of memory if not handled carefully.
#
# Garbage collector overhead: The garbage collector runs automatically, but managing many objects can slow down performance.
#
# 🔹 24. How do you raise an exception manually in Python?
# Use the raise keyword with a specific exception type.
#
# Example:
#
# python
# Copy
# Edit
# age = -5
# if age < 0:
#     raise ValueError("Age cannot be negative")
# You can raise built-in exceptions or define your own custom ones.
#
# 🔹 25. Why is it important to use multithreading in certain applications?
# Multithreading is useful when:
#
# Your program is I/O-bound (e.g., reading files, downloading from the internet).
#
# You want to keep the application responsive (e.g., GUI apps)

# %%
# prompt: &F How can you open a file for writing in Python and write a string to it

with open("my_new_file.txt", "w") as f:
    f.write("Hello, this is a test string written to a file.")

# %%
# prompt: F Write a Python program to read the contents of a file and print each line

file_path = "my_new_file.txt"

try:
  with open(file_path, 'r') as f:
    for line in f:
      print(line, end='') # Use end='' to avoid double newlines
except FileNotFoundError:
  print(f"Error: File '{file_path}' not found.")
except Exception as e:
  print(f"An error occurred: {e}")
# Out:
# Hello, this is a test string written to a file.
# /usr/local/lib/python3.11/dist-packages/IPython/core/inputtransformer2.py:478: UserWarning: `make_tokens_by_line` received a list of lines which do not have lineending markers ('\n', '\r', '\r\n', '\x0b', '\x0c'), behavior will be unspecified
#   warnings.warn("`make_tokens_by_line` received a list of lines which do not have lineending markers ('\\n', '\\r', '\\r\\n', '\\x0b', '\\x0c'), behavior will be unspecified")

# %%
# prompt: =F How would you handle a case where the file doesn't exist while trying to open it for reading

file_path = "non_existent_file.txt" # Replace with the actual file path

try:
  with open(file_path, 'r') as f:
    # Process the file content
    for line in f:
      print(line, end='')
except FileNotFoundError:
  print(f"Error: The file '{file_path}' was not found.")
except Exception as e:
  print(f"An unexpected error occurred: {e}")
# Out:
# Error: The file 'non_existent_file.txt' was not found.

# %%
# prompt: 7F Write a Python script that reads from one file and writes its content to another file

# Define the input and output file names
input_filename = "my_new_file.txt"  # Replace with your actual input filename
output_filename = "output_file.txt" # Replace with your desired output filename

try:
  # Open the input file for reading
  with open(input_filename, 'r') as infile:
    # Read the entire content of the input file
    content = infile.read()

  # Open the output file for writing
  with open(output_filename, 'w') as outfile:
    # Write the content to the output file
    outfile.write(content)

  print(f"Content successfully copied from '{input_filename}' to '{output_filename}'.")

except FileNotFoundError:
  print(f"Error: The file '{input_filename}' was not found.")
except Exception as e:
  print(f"An error occurred: {e}")
# Out:
# Content successfully copied from 'my_new_file.txt' to 'output_file.txt'.

# %%
# prompt: :F How would you catch and handle division by zero error in Python

try:
  numerator = 10
  denominator = 0
  result = numerator / denominator
  print(result)
except ZeroDivisionError:
  print("Error: Division by zero occurred.")
except Exception as e:
  print(f"An unexpected error occurred: {e}")
# Out:
# Error: Division by zero occurred.

# %%
# prompt: )F Write a Python program that logs an error message to a log file when a division by zero exception occursF

import logging

# Configure logging to write to a file
logging.basicConfig(filename='error.log', level=logging.ERROR,
                    format='%(asctime)s:%(levelname)s:%(message)s')

try:
  numerator = 10
  denominator = 0
  result = numerator / denominator
  print(result)
except ZeroDivisionError:
  # Log the error message
  logging.error("Attempted to divide by zero.")
  print("Error: Division by zero occurred. Details logged to error.log")
except Exception as e:
  # Log any other unexpected errors
  logging.error(f"An unexpected error occurred: {e}")
  print(f"An unexpected error occurred: {e}. Details logged to error.log")
# Out:
# ERROR:root:Attempted to divide by zero.
# Error: Division by zero occurred. Details logged to error.log

# %%
# prompt: F How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module

# Configure the root logger
logging.basicConfig(level=logging.INFO,
                    format='%(asctime)s - %(levelname)s - %(message)s')

# Log messages at different levels
logging.info("This is an informational message.")
logging.warning("This is a warning message.")
logging.error("This is an error message.")
# Out:
# WARNING:root:This is a warning message.
# ERROR:root:This is an error message.

# %%
# prompt: F Write a program to handle a file opening error using exception handlingF

file_name = "non_existent_file.txt"  # Or any file name you want to try to open

try:
    with open(file_name, 'r') as file:
        print(f"Successfully opened and read '{file_name}'")
        # You can add code here to process the file content if needed
except FileNotFoundError:
    print(f"Error: The file '{file_name}' was not found.")
except IOError as e:
    print(f"An input/output error occurred: {e}")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
finally:
    print("Attempted to open the file.")
# Out:
# Error: The file 'non_existent_file.txt' was not found.
# Attempted to open the file.

# %%
# prompt: F How can you read a file line by line and store its content in a list in Python

file_path = "my_new_file.txt"  # Replace with the actual path to your file
lines_list = []

try:
    with open(file_path, 'r') as file:
        for line in file:
            lines_list.append(line.strip()) # Use strip() to remove leading/trailing whitespace (including newline)
except FileNotFoundError:
    print(f"Error: The file '{file_path}' was not found.")
except Exception as e:
    print(f"An error occurred: {e}")

# Now lines_list contains each line of the file as an element in the list
lines_list
# Out:
# ['Hello, this is a test string written to a file.']

# %%
# prompt: &F How can you append data to an existing file in Python

# Specify the file path
file_path = "my_new_file.txt"  # Replace with the actual path to your file

# Data to append
data_to_append = "\nThis is the new line being appended."

try:
  # Open the file in append mode ('a')
  with open(file_path, 'a') as file:
    # Write the data to the end of the file
    file.write(data_to_append)

  print(f"Data successfully appended to '{file_path}'.")

except FileNotFoundError:
  print(f"Error: The file '{file_path}' was not found.")
except Exception as e:
  print(f"An error occurred: {e}")
# Out:
# Data successfully appended to 'my_new_file.txt'.

# %%
# prompt: &&F Write a Python program that uses a try-except block to handle an error when attempting to access a
# dictionary key that doesn't exist

my_dict = {"name": "Alice", "age": 30}

try:
  value = my_dict["city"]
  print(value)
except KeyError:
  print("Error: The requested key does not exist in the dictionary.")
except Exception as e:
  print(f"An unexpected error occurred: {e}")
# Out:
# Error: The requested key does not exist in the dictionary.

# %%
# prompt: &F Write a program that demonstrates using multiple except blocks to handle different types of exceptionsF

try:
    # Code that might raise different exceptions
    x = int(input("Enter a number: "))
    y = 1 / x
    print(f"Result: {y}")
    my_list = [1, 2]
    print(my_list[5])

except ZeroDivisionError:
    print("Error: Cannot divide by zero.")
except ValueError:
    print("Error: Invalid input. Please enter an integer.")
except IndexError:
    print("Error: List index out of range.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/inputtransformer2.py:478: UserWarning: `make_tokens_by_line` received a list of lines which do not have lineending markers ('\n', '\r', '\r\n', '\x0b', '\x0c'), behavior will be unspecified
#   warnings.warn("`make_tokens_by_line` received a list of lines which do not have lineending markers ('\\n', '\\r', '\\r\\n', '\\x0b', '\\x0c'), behavior will be unspecified")
# Enter a number: 12
# Result: 0.08333333333333333
# Error: List index out of range.

# %%
# prompt: &=F How would you check if a file exists before attempting to read it in Python

import os

file_path = "my_new_file.txt"  # Replace with the actual path to your file

if os.path.exists(file_path):
  try:
    with open(file_path, 'r') as file:
      # Read or process the file
      content = file.read()
      print("File exists and content read successfully:")
      print(content)
  except IOError as e:
    print(f"An input/output error occurred while reading the file: {e}")
  except Exception as e:
    print(f"An unexpected error occurred while reading the file: {e}")
else:
  print(f"The file '{file_path}' does not exist.")
# Out:
# File exists and content read successfully:
# Hello, this is a test string written to a file.
# This is the new line being appended.

# %%
# prompt: &7F Write a program that uses the logging module to log both informational and error messages

# Configure logging to the console with different levels
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

def process_data(data):
  """Processes data and logs information and errors."""
  if data is None:
    logging.error("process_data received None input.")
    raise ValueError("Input data cannot be None")

  if not isinstance(data, list):
    logging.warning("process_data expected a list, but received a different type.")

  try:
    # Example of an informational message
    logging.info(f"Starting data processing for {len(data)} items.")

    # Simulate some processing that might cause an error
    for item in data:
        if item == 0:
            # Simulate an error condition
            result = 10 / item
        else:
            # Simulate successful processing
            result = item * 2
        logging.debug(f"Processed item {item}, result: {result}")

    logging.info("Data processing completed successfully.")

  except ZeroDivisionError:
    logging.error("ZeroDivisionError occurred during data processing.")
    print("Error: Cannot divide by zero in data processing.")
  except Exception as e:
    logging.error(f"An unexpected error occurred during data processing: {e}")
    print(f"An unexpected error occurred during data processing: {e}")


# Example usage
data1 = [1, 2, 3, 4, 5]
process_data(data1)

print("-" * 20)

data2 = [1, 2, 0, 4, 5] # This will cause a ZeroDivisionError
process_data(data2)

print("-" * 20)

data3 = None # This will raise a ValueError
try:
  process_data(data3)
except ValueError as e:
  print(f"Caught expected exception: {e}")

print("-" * 20)

data4 = "not a list" # This will trigger a warning
process_data(data4)
# Out:
# ERROR:root:ZeroDivisionError occurred during data processing.
# ERROR:root:process_data received None input.
# WARNING:root:process_data expected a list, but received a different type.
# --------------------
# Error: Cannot divide by zero in data processing.
# --------------------
# Caught expected exception: Input data cannot be None
# --------------------

# %%
# prompt: &:F Write a Python program that prints the content of a file and handles the case when the file is emptyF

def print_file_content(filename):
  """
  Prints the content of a file. Handles FileNotFoundError and empty files.

  Args:
    filename: The path to the file.
  """
  try:
    with open(filename, 'r') as file:
      content = file.read()
      if not content:
        print(f"The file '{filename}' is empty.")
      else:
        print(f"Content of '{filename}':")
        print(content)
  except FileNotFoundError:
    print(f"Error: The file '{filename}' was not found.")
  except Exception as e:
    print(f"An error occurred while reading '{filename}': {e}")

# Example usage with an existing file (assuming 'my_new_file.txt' was created earlier)
print_file_content("my_new_file.txt")

# Example usage with a non-existent file
print_file_content("non_existent_file.txt")

# Create an empty file for demonstration
empty_file_name = "empty_file.txt"
with open(empty_file_name, "w") as f:
    pass # Create an empty file

# Example usage with an empty file
print_file_content(empty_file_name)

# Clean up the empty file
os.remove(empty_file_name)
# Out:
# Content of 'my_new_file.txt':
# Hello, this is a test string written to a file.
# This is the new line being appended.
# Error: The file 'non_existent_file.txt' was not found.
# The file 'empty_file.txt' is empty.

# %%
# prompt: &)F Demonstrate how to use memory profiling to check the memory usage of a small programF

# !pip install memory_profiler

# Enable the memory profiler extension
# %load_ext memory_profiler

def create_large_list(size):
  """Creates a large list of integers."""
  return [i for i in range(size)]

# Define the size of the list
list_size = 1000000 # Adjust size to see noticeable memory usage

# Use %memit to profile the memory usage of a single line of code
# %memit large_list = create_large_list(list_size)

# Alternatively, use %%memit to profile a block of code
# %%memit
# large_list = create_large_list(list_size)
# another_list = create_large_list(list_size // 2)

# Clean up the large list to free memory
del large_list

# Example of profiling a function
# @profile # Uncomment this line and run as a script (not in notebook) or use mprof run
# def my_function():
#   a = [1] * 1000000
#   b = [2] * 2000000
#   del b
#   return a

# my_function()
# Out:
# Collecting memory_profiler
#   Downloading memory_profiler-0.61.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from memory_profiler) (5.9.5)
# Downloading memory_profiler-0.61.0-py3-none-any.whl (31 kB)
# Installing collected packages: memory_profiler
# Successfully installed memory_profiler-0.61.0
# peak memory: 150.84 MiB, increment: 34.37 MiB

# %%
# prompt: &F Write a Python program to create and write a list of numbers to a file, one number per lineF

def write_numbers_to_file(filename, numbers):
  """
  Writes a list of numbers to a file, one number per line.

  Args:
    filename (str): The name of the file to write to.
    numbers (list): A list of numbers to write.
  """
  try:
    with open(filename, 'w') as f:
      for number in numbers:
        f.write(str(number) + '\n')
    print(f"Numbers successfully written to '{filename}'.")
  except IOError as e:
    print(f"Error writing to file '{filename}': {e}")
  except Exception as e:
    print(f"An unexpected error occurred: {e}")

# Example usage:
my_numbers = [10, 25, 5, 42, 99, 1, 7]
file_to_write = "numbers_list.txt"

write_numbers_to_file(file_to_write, my_numbers)

# Optional: Read the file back to verify the content
try:
    with open(file_to_write, 'r') as f:
        print("\nContent of the created file:")
        print(f.read())
except FileNotFoundError:
    print(f"Error: The file '{file_to_write}' was not found after writing.")
except Exception as e:
    print(f"An error occurred while reading the file: {e}")
# Out:
# Numbers successfully written to 'numbers_list.txt'.
#
# Content of the created file:
# 10
# 25
# 5
# 42
# 99
# 1
# 7

# %%
# prompt: &F How would you implement a basic logging setup that logs to a file with rotation after 1MB

from logging.handlers import RotatingFileHandler

# Define the log file path and size
LOG_FILE = 'my_app.log'
MAX_BYTES = 1024 * 1024 # 1MB
BACKUP_COUNT = 5 # Keep up to 5 old log files

# Create a logger
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO) # Set the minimum logging level

# Create a RotatingFileHandler
handler = RotatingFileHandler(LOG_FILE, maxBytes=MAX_BYTES, backupCount=BACKUP_COUNT)

# Create a formatter
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')

# Set the formatter for the handler
handler.setFormatter(formatter)

# Add the handler to the logger
logger.addHandler(handler)

# Example usage:
logger.info("Application started.")
logger.warning("This is a warning.")
logger.error("This is an error message.")

# Simulate writing enough to trigger rotation
# You would typically have this spread out in your application's lifetime
for i in range(10000): # Adjust the range to control how much data is written
    logger.info(f"Writing log message number {i + 1} to test rotation.")

logger.info("Application finished.")

# You can check the contents of 'my_app.log' and 'my_app.log.1', etc. in your file system
# To see the files in Colab:
# !ls -l my_app.log*
# To view a file:
# !cat my_app.log
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:__main__:Writing log message number 5002 to test rotation.
# INFO:__main__:Writing log message number 5003 to test rotation.
# INFO:__main__:Writing log message number 5004 to test rotation.
# INFO:__main__:Writing log message number 5005 to test rotation.
# INFO:__main__:Writing log message number 5006 to test rotation.
# INFO:__main__:Writing log message number 5007 to test rotation.
# INFO:__main__:Writing log message number 5008 to test rotation.
# INFO:__main__:Writing log message number 5009 to test rotation.
# INFO:__main__:Writing log message number 5010 to test rotation.
# INFO:__main__:Writing log message number 5011 to test rotation.
# INFO:__main__:Writing log message number 5012 to test rotation.
# INFO:__main__:Writing log message number 5013 to test rotation.
# INFO:__main__:Writing log message number 5014 to test rotation.
# INFO:__main__:Writing log message number 5015 to test rotation.
# INFO:__main__:Writing log message number 5016 to test rotation.
# INFO:__main__:Writing log message number 5017 to test rotation.
# INFO:__main__:Writing log message number 5018 to test rotation.
# INFO:__main__:Writing log message number 5019 to test rotation.
# INFO:__main__:Writing log message number 5020 to test rotation.
# INFO:__main__:Writing log message number 5021 to test rotation.
# INFO:__main__:Writing log message number 5022 to test rotation.
# INFO:__main__:Writing log message number 5023 to test rotation.
# INFO:__main__:Writing log message number 5024 to test rotation.
# INFO:__main__:Writing log message number 5025 to test rotation.
# INFO:__main__:Writing log message number 5026 to test rotation.
# INFO:__main__:Writing log message number 5027 to test rotation.
# INFO:__main__:Writing log message number 5028 to test rotation.
# INFO:__main__:Writing log message number 5029 to test rotation.
# INFO:__main__:Writing log message number 5030 to test rotation.
# INFO:__main__:Writing log message number 5031 to test rotation.
# INFO:__main__:Writing log message number 5032 to test rotation.
# INFO:__main__:Writing log message number 5033 to test rotation.
# INFO:__main__:Writing log message number 5034 to test rotation.
# INFO:__main__:Writing log message number 5035 to test rotation.
# INFO:__main__:Writing log message number 5036 to test rotation.
# INFO:__main__:Writing log message number 5037 to test rotation.
# INFO:__main__:Writing log message number 5038 to test rotation.
# INFO:__main__:Writing log message number 5039 to test rotation.
# INFO:__main__:Writing log message number 5040 to test rotation.
# INFO:__main__:Writing log message number 5041 to test rotation.
# INFO:__main__:Writing log message number 5042 to test rotation.
# INFO:__main__:Writing log message number 5043 to test rotation.
# INFO:__main__:Writing log message number 5044 to test rotation.
# INFO:__main__:Writing log message number 5045 to test rotation.
# INFO:__main__:Writing log message number 5046 to test rotation.
# INFO:__main__:Writing log message number 5047 to test rotation.
# INFO:__main__:Writing log message number 5048 to test rotation.
# INFO:__main__:Writing log message number 5049 to test rotation.
# INFO:__main__:Writing log message number 5050 to test rotation.
# INFO:__main__:Writing log message number 5051 to test rotation.
# INFO:__main__:Writing log message number 5052 to test rotation.
# INFO:__main__:Writing log message number 5053 to test rotation.
# INFO:__main__:Writing log message number 5054 to test rotation.
# INFO:__main__:Writing log message number 5055 to test rotation.
# INFO:__main__:Writing log message number 5056 to test rotation.
# INFO:__main__:Writing log message number 5057 to test rotation.
# INFO:__main__:Writing log message number 5058 to test rotation.
# INFO:__main__:Writing log message number 5059 to test rotation.
# INFO:__main__:Writing log message number 5060 to test rotation.
# INFO:__main__:Writing log message number 5061 to test rotation.
# INFO:__main__:Writing log message number 5062 to test rotation.
# INFO:__main__:Writing log message number 5063 to test rotation.
# INFO:__main__:Writing log message number 5064 to test rotation.
# INFO:__main__:Writing log message number 5065 to test rotation.
# INFO:__main__:Writing log message number 5066 to test rotation.
# INFO:__main__:Writing log message number 5067 to test rotation.
# INFO:__main__:Writing log message number 5068 to test rotation.
# INFO:__main__:Writing log message number 5069 to test rotation.
# INFO:__main__:Writing log message number 5070 to test rotation.
# INFO:__main__:Writing log message number 5071 to test rotation.
# INFO:__main__:Writing log message number 5072 to test rotation.
# INFO:__main__:Writing log message number 5073 to test rotation.
# INFO:__main__:Writing log message number 5074 to test rotation.
# INFO:__main__:Writing log message number 5075 to test rotation.
# INFO:__main__:Writing log message number 5076 to test rotation.
# INFO:__main__:Writing log message number 5077 to test rotation.
# INFO:__main__:Writing log message number 5078 to test rotation.
# INFO:__main__:Writing log message number 5079 to test rotation.
# INFO:__main__:Writing log message number 5080 to test rotation.
# INFO:__main__:Writing log message number 5081 to test rotation.
# INFO:__main__:Writing log message number 5082 to test rotation.
# INFO:__main__:Writing log message number 5083 to test rotation.
# INFO:__main__:Writing log message number 5084 to test rotation.
# INFO:__main__:Writing log message number 5085 to test rotation.
# INFO:__main__:Writing log message number 5086 to test rotation.
# INFO:__main__:Writing log message number 5087 to test rotation.
# INFO:__main__:Writing log message number 5088 to test rotation.
# INFO:__main__:Writing log message number 5089 to test rotation.
# INFO:__main__:Writing log message number 5090 to test rotation.
# INFO:__main__:Writing log message number 5091 to test rotation.
# INFO:__main__:Writing log message number 5092 to test rotation.
# INFO:__main__:Writing log message number 5093 to test rotation.
# INFO:__main__:Writing log message number 5094 to test rotation.
# INFO:__main__:Writing log message number 5095 to test rotation.
# INFO:__main__:Writing log message number 5096 to test rotation.
# INFO:__main__:Writing log message number 5097 to test rotation.
# INFO:__main__:Writing log message number 5098 to test rotation.
# INFO:__main__:Writing log message number 5099 to test rotation.
# INFO:__main__:Writing log message number 5100 to test rotation.
# INFO:__main__:Writing log message number 5101 to test rotation.
# INFO:__main__:Writing log message number 5102 to test rotation.
# INFO:__main__:Writing log message number 5103 to test rotation.
# INFO:__main__:Writing log message number 5104 to test rotation.
# INFO:__main__:Writing log message number 5105 to test rotation.
# INFO:__main__:Writing log message number 5106 to test rotation.
# INFO:__main__:Writing log message number 5107 to test rotation.
# INFO:__main__:Writing log message number 5108 to test rotation.
# INFO:__main__:Writing log message number 5109 to test rotation.
# INFO:__main__:Writing log message number 5110 to test rotation.
# INFO:__main__:Writing log message number 5111 to test rotation.
# INFO:__main__:Writing log message number 5112 to test rotation.
# INFO:__main__:Writing log message number 5113 to test rotation.
# INFO:__main__:Writing log message number 5114 to test rotation.
# INFO:__main__:Writing log message number 5115 to test rotation.
# INFO:__main__:Writing log message number 5116 to test rotation.
# INFO:__main__:Writing log message number 5117 to test rotation.
# INFO:__main__:Writing log message number 5118 to test rotation.
# INFO:__main__:Writing log message number 5119 to test rotation.
# INFO:__main__:Writing log message number 5120 to test rotation.
# INFO:__main__:Writing log message number 5121 to test rotation.
# INFO:__main__:Writing log message number 5122 to test rotation.
# INFO:__main__:Writing log message number 5123 to test rotation.
# INFO:__main__:Writing log message number 5124 to test rotation.
# INFO:__main__:Writing log message number 5125 to test rotation.
# INFO:__main__:Writing log message number 5126 to test rotation.
# INFO:__main__:Writing log message number 5127 to test rotation.
# INFO:__main__:Writing log message number 5128 to test rotation.
# INFO:__main__:Writing log message number 5129 to test rotation.
# INFO:__main__:Writing log message number 5130 to test rotation.
# INFO:__main__:Writing log message number 5131 to test rotation.
# INFO:__main__:Writing log message number 5132 to test rotation.
# INFO:__main__:Writing log message number 5133 to test rotation.
# INFO:__main__:Writing log message number 5134 to test rotation.
# INFO:__main__:Writing log message number 5135 to test rotation.
# INFO:__main__:Writing log message number 5136 to test rotation.
# INFO:__main__:Writing log message number 5137 to test rotation.
# INFO:__main__:Writing log message number 5138 to test rotation.
# INFO:__main__:Writing log message number 5139 to test rotation.
# INFO:__main__:Writing log message number 5140 to test rotation.
# INFO:__main__:Writing log message number 5141 to test rotation.
# INFO:__main__:Writing log message number 5142 to test rotation.
# INFO:__main__:Writing log message number 5143 to test rotation.
# INFO:__main__:Writing log message number 5144 to test rotation.
# INFO:__main__:Writing log message number 5145 to test rotation.
# INFO:__main__:Writing log message number 5146 to test rotation.
# INFO:__main__:Writing log message number 5147 to test rotation.
# INFO:__main__:Writing log message number 5148 to test rotation.
# INFO:__main__:Writing log message number 5149 to test rotation.
# INFO:__main__:Writing log message number 5150 to test rotation.
# INFO:__main__:Writing log message number 5151 to test rotation.
# INFO:__main__:Writing log message number 5152 to test rotation.
# INFO:__main__:Writing log message number 5153 to test rotation.
# INFO:__main__:Writing log message number 5154 to test rotation.
# INFO:__main__:Writing log message number 5155 to test rotation.
# INFO:__main__:Writing log message number 5156 to test rotation.
# INFO:__main__:Writing log message number 5157 to test rotation.
# INFO:__main__:Writing log message number 5158 to test rotation.
# INFO:__main__:Writing log message number 5159 to test rotation.
# INFO:__main__:Writing log message number 5160 to test rotation.
# INFO:__main__:Writing log message number 5161 to test rotation.
# INFO:__main__:Writing log message number 5162 to test rotation.
# INFO:__main__:Writing log message number 5163 to test rotation.
# INFO:__main__:Writing log message number 5164 to test rotation.
# INFO:__main__:Writing log message number 5165 to test rotation.
# INFO:__main__:Writing log message number 5166 to test rotation.
# INFO:__main__:Writing log message number 5167 to test rotation.
# INFO:__main__:Writing log message number 5168 to test rotation.
# INFO:__main__:Writing log message number 5169 to test rotation.
# INFO:__main__:Writing log message number 5170 to test rotation.
# INFO:__main__:Writing log message number 5171 to test rotation.
# INFO:__main__:Writing log message number 5172 to test rotation.
# INFO:__main__:Writing log message number 5173 to test rotation.
# INFO:__main__:Writing log message number 5174 to test rotation.
# INFO:__main__:Writing log message number 5175 to test rotation.
# INFO:__main__:Writing log message number 5176 to test rotation.
# INFO:__main__:Writing log message number 5177 to test rotation.
# INFO:__main__:Writing log message number 5178 to test rotation.
# INFO:__main__:Writing log message number 5179 to test rotation.
# INFO:__main__:Writing log message number 5180 to test rotation.
# INFO:__main__:Writing log message number 5181 to test rotation.
# INFO:__main__:Writing log message number 5182 to test rotation.
# INFO:__main__:Writing log message number 5183 to test rotation.
# INFO:__main__:Writing log message number 5184 to test rotation.
# INFO:__main__:Writing log message number 5185 to test rotation.
# INFO:__main__:Writing log message number 5186 to test rotation.
# INFO:__main__:Writing log message number 5187 to test rotation.
# INFO:__main__:Writing log message number 5188 to test rotation.
# INFO:__main__:Writing log message number 5189 to test rotation.
# INFO:__main__:Writing log message number 5190 to test rotation.
# INFO:__main__:Writing log message number 5191 to test rotation.
# INFO:__main__:Writing log message number 5192 to test rotation.
# INFO:__main__:Writing log message number 5193 to test rotation.
# INFO:__main__:Writing log message number 5194 to test rotation.
# INFO:__main__:Writing log message number 5195 to test rotation.
# INFO:__main__:Writing log message number 5196 to test rotation.
# INFO:__main__:Writing log message number 5197 to test rotation.
# INFO:__main__:Writing log message number 5198 to test rotation.
# INFO:__main__:Writing log message number 5199 to test rotation.
# INFO:__main__:Writing log message number 5200 to test rotation.
# INFO:__main__:Writing log message number 5201 to test rotation.
# INFO:__main__:Writing log message number 5202 to test rotation.
# INFO:__main__:Writing log message number 5203 to test rotation.
# INFO:__main__:Writing log message number 5204 to test rotation.
# INFO:__main__:Writing log message number 5205 to test rotation.
# INFO:__main__:Writing log message number 5206 to test rotation.
# INFO:__main__:Writing log message number 5207 to test rotation.
# INFO:__main__:Writing log message number 5208 to test rotation.
# INFO:__main__:Writing log message number 5209 to test rotation.
# INFO:__main__:Writing log message number 5210 to test rotation.
# INFO:__main__:Writing log message number 5211 to test rotation.
# INFO:__main__:Writing log message number 5212 to test rotation.
# INFO:__main__:Writing log message number 5213 to test rotation.
# INFO:__main__:Writing log message number 5214 to test rotation.
# INFO:__main__:Writing log message number 5215 to test rotation.
# INFO:__main__:Writing log message number 5216 to test rotation.
# INFO:__main__:Writing log message number 5217 to test rotation.
# INFO:__main__:Writing log message number 5218 to test rotation.
# INFO:__main__:Writing log message number 5219 to test rotation.
# INFO:__main__:Writing log message number 5220 to test rotation.
# INFO:__main__:Writing log message number 5221 to test rotation.
# INFO:__main__:Writing log message number 5222 to test rotation.
# INFO:__main__:Writing log message number 5223 to test rotation.
# INFO:__main__:Writing log message number 5224 to test rotation.
# INFO:__main__:Writing log message number 5225 to test rotation.
# INFO:__main__:Writing log message number 5226 to test rotation.
# INFO:__main__:Writing log message number 5227 to test rotation.
# INFO:__main__:Writing log message number 5228 to test rotation.
# INFO:__main__:Writing log message number 5229 to test rotation.
# INFO:__main__:Writing log message number 5230 to test rotation.
# INFO:__main__:Writing log message number 5231 to test rotation.
# INFO:__main__:Writing log message number 5232 to test rotation.
# INFO:__main__:Writing log message number 5233 to test rotation.
# INFO:__main__:Writing log message number 5234 to test rotation.
# INFO:__main__:Writing log message number 5235 to test rotation.
# INFO:__main__:Writing log message number 5236 to test rotation.
# INFO:__main__:Writing log message number 5237 to test rotation.
# INFO:__main__:Writing log message number 5238 to test rotation.
# INFO:__main__:Writing log message number 5239 to test rotation.
# INFO:__main__:Writing log message number 5240 to test rotation.
# INFO:__main__:Writing log message number 5241 to test rotation.
# INFO:__main__:Writing log message number 5242 to test rotation.
# INFO:__main__:Writing log message number 5243 to test rotation.
# INFO:__main__:Writing log message number 5244 to test rotation.
# INFO:__main__:Writing log message number 5245 to test rotation.
# INFO:__main__:Writing log message number 5246 to test rotation.
# INFO:__main__:Writing log message number 5247 to test rotation.
# INFO:__main__:Writing log message number 5248 to test rotation.
# INFO:__main__:Writing log message number 5249 to test rotation.
# INFO:__main__:Writing log message number 5250 to test rotation.
# INFO:__main__:Writing log message number 5251 to test rotation.
# INFO:__main__:Writing log message number 5252 to test rotation.
# INFO:__main__:Writing log message number 5253 to test rotation.
# INFO:__main__:Writing log message number 5254 to test rotation.
# INFO:__main__:Writing log message number 5255 to test rotation.
# INFO:__main__:Writing log message number 5256 to test rotation.
# INFO:__main__:Writing log message number 5257 to test rotation.
# INFO:__main__:Writing log message number 5258 to test rotation.
# INFO:__main__:Writing log message number 5259 to test rotation.
# INFO:__main__:Writing log message number 5260 to test rotation.
# INFO:__main__:Writing log message number 5261 to test rotation.
# INFO:__main__:Writing log message number 5262 to test rotation.
# INFO:__main__:Writing log message number 5263 to test rotation.
# INFO:__main__:Writing log message number 5264 to test rotation.
# INFO:__main__:Writing log message number 5265 to test rotation.
# INFO:__main__:Writing log message number 5266 to test rotation.
# INFO:__main__:Writing log message number 5267 to test rotation.
# INFO:__main__:Writing log message number 5268 to test rotation.
# INFO:__main__:Writing log message number 5269 to test rotation.
# INFO:__main__:Writing log message number 5270 to test rotation.
# INFO:__main__:Writing log message number 5271 to test rotation.
# INFO:__main__:Writing log message number 5272 to test rotation.
# INFO:__main__:Writing log message number 5273 to test rotation.
# INFO:__main__:Writing log message number 5274 to test rotation.
# INFO:__main__:Writing log message number 5275 to test rotation.
# INFO:__main__:Writing log message number 5276 to test rotation.
# INFO:__main__:Writing log message number 5277 to test rotation.
# INFO:__main__:Writing log message number 5278 to test rotation.
# INFO:__main__:Writing log message number 5279 to test rotation.
# INFO:__main__:Writing log message number 5280 to test rotation.
# INFO:__main__:Writing log message number 5281 to test rotation.
# INFO:__main__:Writing log message number 5282 to test rotation.
# INFO:__main__:Writing log message number 5283 to test rotation.
# INFO:__main__:Writing log message number 5284 to test rotation.
# INFO:__main__:Writing log message number 5285 to test rotation.
# INFO:__main__:Writing log message number 5286 to test rotation.
# INFO:__main__:Writing log message number 5287 to test rotation.
# INFO:__main__:Writing log message number 5288 to test rotation.
# INFO:__main__:Writing log message number 5289 to test rotation.
# INFO:__main__:Writing log message number 5290 to test rotation.
# INFO:__main__:Writing log message number 5291 to test rotation.
# INFO:__main__:Writing log message number 5292 to test rotation.
# INFO:__main__:Writing log message number 5293 to test rotation.
# INFO:__main__:Writing log message number 5294 to test rotation.
# INFO:__main__:Writing log message number 5295 to test rotation.
# INFO:__main__:Writing log message number 5296 to test rotation.
# INFO:__main__:Writing log message number 5297 to test rotation.
# INFO:__main__:Writing log message number 5298 to test rotation.
# INFO:__main__:Writing log message number 5299 to test rotation.
# INFO:__main__:Writing log message number 5300 to test rotation.
# INFO:__main__:Writing log message number 5301 to test rotation.
# INFO:__main__:Writing log message number 5302 to test rotation.
# INFO:__main__:Writing log message number 5303 to test rotation.
# INFO:__main__:Writing log message number 5304 to test rotation.
# INFO:__main__:Writing log message number 5305 to test rotation.
# INFO:__main__:Writing log message number 5306 to test rotation.
# INFO:__main__:Writing log message number 5307 to test rotation.
# INFO:__main__:Writing log message number 5308 to test rotation.
# INFO:__main__:Writing log message number 5309 to test rotation.
# INFO:__main__:Writing log message number 5310 to test rotation.
# INFO:__main__:Writing log message number 5311 to test rotation.
# INFO:__main__:Writing log message number 5312 to test rotation.
# INFO:__main__:Writing log message number 5313 to test rotation.
# INFO:__main__:Writing log message number 5314 to test rotation.
# INFO:__main__:Writing log message number 5315 to test rotation.
# INFO:__main__:Writing log message number 5316 to test rotation.
# INFO:__main__:Writing log message number 5317 to test rotation.
# INFO:__main__:Writing log message number 5318 to test rotation.
# INFO:__main__:Writing log message number 5319 to test rotation.
# INFO:__main__:Writing log message number 5320 to test rotation.
# INFO:__main__:Writing log message number 5321 to test rotation.
# INFO:__main__:Writing log message number 5322 to test rotation.
# INFO:__main__:Writing log message number 5323 to test rotation.
# INFO:__main__:Writing log message number 5324 to test rotation.
# INFO:__main__:Writing log message number 5325 to test rotation.
# INFO:__main__:Writing log message number 5326 to test rotation.
# INFO:__main__:Writing log message number 5327 to test rotation.
# INFO:__main__:Writing log message number 5328 to test rotation.
# INFO:__main__:Writing log message number 5329 to test rotation.
# INFO:__main__:Writing log message number 5330 to test rotation.
# INFO:__main__:Writing log message number 5331 to test rotation.
# INFO:__main__:Writing log message number 5332 to test rotation.
# INFO:__main__:Writing log message number 5333 to test rotation.
# INFO:__main__:Writing log message number 5334 to test rotation.
# INFO:__main__:Writing log message number 5335 to test rotation.
# INFO:__main__:Writing log message number 5336 to test rotation.
# INFO:__main__:Writing log message number 5337 to test rotation.
# INFO:__main__:Writing log message number 5338 to test rotation.
# INFO:__main__:Writing log message number 5339 to test rotation.
# INFO:__main__:Writing log message number 5340 to test rotation.
# INFO:__main__:Writing log message number 5341 to test rotation.
# INFO:__main__:Writing log message number 5342 to test rotation.
# INFO:__main__:Writing log message number 5343 to test rotation.
# INFO:__main__:Writing log message number 5344 to test rotation.
# INFO:__main__:Writing log message number 5345 to test rotation.
# INFO:__main__:Writing log message number 5346 to test rotation.
# INFO:__main__:Writing log message number 5347 to test rotation.
# INFO:__main__:Writing log message number 5348 to test rotation.
# INFO:__main__:Writing log message number 5349 to test rotation.
# INFO:__main__:Writing log message number 5350 to test rotation.
# INFO:__main__:Writing log message number 5351 to test rotation.
# INFO:__main__:Writing log message number 5352 to test rotation.
# INFO:__main__:Writing log message number 5353 to test rotation.
# INFO:__main__:Writing log message number 5354 to test rotation.
# INFO:__main__:Writing log message number 5355 to test rotation.
# INFO:__main__:Writing log message number 5356 to test rotation.
# INFO:__main__:Writing log message number 5357 to test rotation.
# INFO:__main__:Writing log message number 5358 to test rotation.
# INFO:__main__:Writing log message number 5359 to test rotation.
# INFO:__main__:Writing log message number 5360 to test rotation.
# INFO:__main__:Writing log message number 5361 to test rotation.
# INFO:__main__:Writing log message number 5362 to test rotation.
# INFO:__main__:Writing log message number 5363 to test rotation.
# INFO:__main__:Writing log message number 5364 to test rotation.
# INFO:__main__:Writing log message number 5365 to test rotation.
# INFO:__main__:Writing log message number 5366 to test rotation.
# INFO:__main__:Writing log message number 5367 to test rotation.
# INFO:__main__:Writing log message number 5368 to test rotation.
# INFO:__main__:Writing log message number 5369 to test rotation.
# INFO:__main__:Writing log message number 5370 to test rotation.
# INFO:__main__:Writing log message number 5371 to test rotation.
# INFO:__main__:Writing log message number 5372 to test rotation.
# INFO:__main__:Writing log message number 5373 to test rotation.
# INFO:__main__:Writing log message number 5374 to test rotation.
# INFO:__main__:Writing log message number 5375 to test rotation.
# INFO:__main__:Writing log message number 5376 to test rotation.
# INFO:__main__:Writing log message number 5377 to test rotation.
# INFO:__main__:Writing log message number 5378 to test rotation.
# INFO:__main__:Writing log message number 5379 to test rotation.
# INFO:__main__:Writing log message number 5380 to test rotation.
# INFO:__main__:Writing log message number 5381 to test rotation.
# INFO:__main__:Writing log message number 5382 to test rotation.
# INFO:__main__:Writing log message number 5383 to test rotation.
# INFO:__main__:Writing log message number 5384 to test rotation.
# INFO:__main__:Writing log message number 5385 to test rotation.
# INFO:__main__:Writing log message number 5386 to test rotation.
# INFO:__main__:Writing log message number 5387 to test rotation.
# INFO:__main__:Writing log message number 5388 to test rotation.
# INFO:__main__:Writing log message number 5389 to test rotation.
# INFO:__main__:Writing log message number 5390 to test rotation.
# INFO:__main__:Writing log message number 5391 to test rotation.
# INFO:__main__:Writing log message number 5392 to test rotation.
# INFO:__main__:Writing log message number 5393 to test rotation.
# INFO:__main__:Writing log message number 5394 to test rotation.
# INFO:__main__:Writing log message number 5395 to test rotation.
# INFO:__main__:Writing log message number 5396 to test rotation.
# INFO:__main__:Writing log message number 5397 to test rotation.
# INFO:__main__:Writing log message number 5398 to test rotation.
# INFO:__main__:Writing log message number 5399 to test rotation.
# INFO:__main__:Writing log message number 5400 to test rotation.
# INFO:__main__:Writing log message number 5401 to test rotation.
# INFO:__main__:Writing log message number 5402 to test rotation.
# INFO:__main__:Writing log message number 5403 to test rotation.
# INFO:__main__:Writing log message number 5404 to test rotation.
# INFO:__main__:Writing log message number 5405 to test rotation.
# INFO:__main__:Writing log message number 5406 to test rotation.
# INFO:__main__:Writing log message number 5407 to test rotation.
# INFO:__main__:Writing log message number 5408 to test rotation.
# INFO:__main__:Writing log message number 5409 to test rotation.
# INFO:__main__:Writing log message number 5410 to test rotation.
# INFO:__main__:Writing log message number 5411 to test rotation.
# INFO:__main__:Writing log message number 5412 to test rotation.
# INFO:__main__:Writing log message number 5413 to test rotation.
# INFO:__main__:Writing log message number 5414 to test rotation.
# INFO:__main__:Writing log message number 5415 to test rotation.
# INFO:__main__:Writing log message number 5416 to test rotation.
# INFO:__main__:Writing log message number 5417 to test rotation.
# INFO:__main__:Writing log message number 5418 to test rotation.
# INFO:__main__:Writing log message number 5419 to test rotation.
# INFO:__main__:Writing log message number 5420 to test rotation.
# INFO:__main__:Writing log message number 5421 to test rotation.
# INFO:__main__:Writing log message number 5422 to test rotation.
# INFO:__main__:Writing log message number 5423 to test rotation.
# INFO:__main__:Writing log message number 5424 to test rotation.
# INFO:__main__:Writing log message number 5425 to test rotation.
# INFO:__main__:Writing log message number 5426 to test rotation.
# INFO:__main__:Writing log message number 5427 to test rotation.
# INFO:__main__:Writing log message number 5428 to test rotation.
# INFO:__main__:Writing log message number 5429 to test rotation.
# INFO:__main__:Writing log message number 5430 to test rotation.
# INFO:__main__:Writing log message number 5431 to test rotation.
# INFO:__main__:Writing log message number 5432 to test rotation.
# INFO:__main__:Writing log message number 5433 to test rotation.
# INFO:__main__:Writing log message number 5434 to test rotation.
# INFO:__main__:Writing log message number 5435 to test rotation.
# INFO:__main__:Writing log message number 5436 to test rotation.
# INFO:__main__:Writing log message number 5437 to test rotation.
# INFO:__main__:Writing log message number 5438 to test rotation.
# INFO:__main__:Writing log message number 5439 to test rotation.
# INFO:__main__:Writing log message number 5440 to test rotation.
# INFO:__main__:Writing log message number 5441 to test rotation.
# INFO:__main__:Writing log message number 5442 to test rotation.
# INFO:__main__:Writing log message number 5443 to test rotation.
# INFO:__main__:Writing log message number 5444 to test rotation.
# INFO:__main__:Writing log message number 5445 to test rotation.
# INFO:__main__:Writing log message number 5446 to test rotation.
# INFO:__main__:Writing log message number 5447 to test rotation.
# INFO:__main__:Writing log message number 5448 to test rotation.
# INFO:__main__:Writing log message number 5449 to test rotation.
# INFO:__main__:Writing log message number 5450 to test rotation.
# INFO:__main__:Writing log message number 5451 to test rotation.
# INFO:__main__:Writing log message number 5452 to test rotation.
# INFO:__main__:Writing log message number 5453 to test rotation.
# INFO:__main__:Writing log message number 5454 to test rotation.
# INFO:__main__:Writing log message number 5455 to test rotation.
# INFO:__main__:Writing log message number 5456 to test rotation.
# INFO:__main__:Writing log message number 5457 to test rotation.
# INFO:__main__:Writing log message number 5458 to test rotation.
# INFO:__main__:Writing log message number 5459 to test rotation.
# INFO:__main__:Writing log message number 5460 to test rotation.
# INFO:__main__:Writing log message number 5461 to test rotation.
# INFO:__main__:Writing log message number 5462 to test rotation.
# INFO:__main__:Writing log message number 5463 to test rotation.
# INFO:__main__:Writing log message number 5464 to test rotation.
# INFO:__main__:Writing log message number 5465 to test rotation.
# INFO:__main__:Writing log message number 5466 to test rotation.
# INFO:__main__:Writing log message number 5467 to test rotation.
# INFO:__main__:Writing log message number 5468 to test rotation.
# INFO:__main__:Writing log message number 5469 to test rotation.
# INFO:__main__:Writing log message number 5470 to test rotation.
# INFO:__main__:Writing log message number 5471 to test rotation.
# INFO:__main__:Writing log message number 5472 to test rotation.
# INFO:__main__:Writing log message number 5473 to test rotation.
# INFO:__main__:Writing log message number 5474 to test rotation.
# INFO:__main__:Writing log message number 5475 to test rotation.
# INFO:__main__:Writing log message number 5476 to test rotation.
# INFO:__main__:Writing log message number 5477 to test rotation.
# INFO:__main__:Writing log message number 5478 to test rotation.
# INFO:__main__:Writing log message number 5479 to test rotation.
# INFO:__main__:Writing log message number 5480 to test rotation.
# INFO:__main__:Writing log message number 5481 to test rotation.
# INFO:__main__:Writing log message number 5482 to test rotation.
# INFO:__main__:Writing log message number 5483 to test rotation.
# INFO:__main__:Writing log message number 5484 to test rotation.
# INFO:__main__:Writing log message number 5485 to test rotation.
# INFO:__main__:Writing log message number 5486 to test rotation.
# INFO:__main__:Writing log message number 5487 to test rotation.
# INFO:__main__:Writing log message number 5488 to test rotation.
# INFO:__main__:Writing log message number 5489 to test rotation.
# INFO:__main__:Writing log message number 5490 to test rotation.
# INFO:__main__:Writing log message number 5491 to test rotation.
# INFO:__main__:Writing log message number 5492 to test rotation.
# INFO:__main__:Writing log message number 5493 to test rotation.
# INFO:__main__:Writing log message number 5494 to test rotation.
# INFO:__main__:Writing log message number 5495 to test rotation.
# INFO:__main__:Writing log message number 5496 to test rotation.
# INFO:__main__:Writing log message number 5497 to test rotation.
# INFO:__main__:Writing log message number 5498 to test rotation.
# INFO:__main__:Writing log message number 5499 to test rotation.
# INFO:__main__:Writing log message number 5500 to test rotation.
# INFO:__main__:Writing log message number 5501 to test rotation.
# INFO:__main__:Writing log message number 5502 to test rotation.
# INFO:__main__:Writing log message number 5503 to test rotation.
# INFO:__main__:Writing log message number 5504 to test rotation.
# INFO:__main__:Writing log message number 5505 to test rotation.
# INFO:__main__:Writing log message number 5506 to test rotation.
# INFO:__main__:Writing log message number 5507 to test rotation.
# INFO:__main__:Writing log message number 5508 to test rotation.
# INFO:__main__:Writing log message number 5509 to test rotation.
# INFO:__main__:Writing log message number 5510 to test rotation.
# INFO:__main__:Writing log message number 5511 to test rotation.
# INFO:__main__:Writing log message number 5512 to test rotation.
# INFO:__main__:Writing log message number 5513 to test rotation.
# INFO:__main__:Writing log message number 5514 to test rotation.
# INFO:__main__:Writing log message number 5515 to test rotation.
# INFO:__main__:Writing log message number 5516 to test rotation.
# INFO:__main__:Writing log message number 5517 to test rotation.
# INFO:__main__:Writing log message number 5518 to test rotation.
# INFO:__main__:Writing log message number 5519 to test rotation.
# INFO:__main__:Writing log message number 5520 to test rotation.
# INFO:__main__:Writing log message number 5521 to test rotation.
# INFO:__main__:Writing log message number 5522 to test rotation.
# INFO:__main__:Writing log message number 5523 to test rotation.
# INFO:__main__:Writing log message number 5524 to test rotation.
# INFO:__main__:Writing log message number 5525 to test rotation.
# INFO:__main__:Writing log message number 5526 to test rotation.
# INFO:__main__:Writing log message number 5527 to test rotation.
# INFO:__main__:Writing log message number 5528 to test rotation.
# INFO:__main__:Writing log message number 5529 to test rotation.
# INFO:__main__:Writing log message number 5530 to test rotation.
# INFO:__main__:Writing log message number 5531 to test rotation.
# INFO:__main__:Writing log message number 5532 to test rotation.
# INFO:__main__:Writing log message number 5533 to test rotation.
# INFO:__main__:Writing log message number 5534 to test rotation.
# INFO:__main__:Writing log message number 5535 to test rotation.
# INFO:__main__:Writing log message number 5536 to test rotation.
# INFO:__main__:Writing log message number 5537 to test rotation.
# INFO:__main__:Writing log message number 5538 to test rotation.
# INFO:__main__:Writing log message number 5539 to test rotation.
# INFO:__main__:Writing log message number 5540 to test rotation.
# INFO:__main__:Writing log message number 5541 to test rotation.
# INFO:__main__:Writing log message number 5542 to test rotation.
# INFO:__main__:Writing log message number 5543 to test rotation.
# INFO:__main__:Writing log message number 5544 to test rotation.
# INFO:__main__:Writing log message number 5545 to test rotation.
# INFO:__main__:Writing log message number 5546 to test rotation.
# INFO:__main__:Writing log message number 5547 to test rotation.
# INFO:__main__:Writing log message number 5548 to test rotation.
# INFO:__main__:Writing log message number 5549 to test rotation.
# INFO:__main__:Writing log message number 5550 to test rotation.
# INFO:__main__:Writing log message number 5551 to test rotation.
# INFO:__main__:Writing log message number 5552 to test rotation.
# INFO:__main__:Writing log message number 5553 to test rotation.
# INFO:__main__:Writing log message number 5554 to test rotation.
# INFO:__main__:Writing log message number 5555 to test rotation.
# INFO:__main__:Writing log message number 5556 to test rotation.
# INFO:__main__:Writing log message number 5557 to test rotation.
# INFO:__main__:Writing log message number 5558 to test rotation.
# INFO:__main__:Writing log message number 5559 to test rotation.
# INFO:__main__:Writing log message number 5560 to test rotation.
# INFO:__main__:Writing log message number 5561 to test rotation.
# INFO:__main__:Writing log message number 5562 to test rotation.
# INFO:__main__:Writing log message number 5563 to test rotation.
# INFO:__main__:Writing log message number 5564 to test rotation.
# INFO:__main__:Writing log message number 5565 to test rotation.
# INFO:__main__:Writing log message number 5566 to test rotation.
# INFO:__main__:Writing log message number 5567 to test rotation.
# INFO:__main__:Writing log message number 5568 to test rotation.
# INFO:__main__:Writing log message number 5569 to test rotation.
# INFO:__main__:Writing log message number 5570 to test rotation.
# INFO:__main__:Writing log message number 5571 to test rotation.
# INFO:__main__:Writing log message number 5572 to test rotation.
# INFO:__main__:Writing log message number 5573 to test rotation.
# INFO:__main__:Writing log message number 5574 to test rotation.
# INFO:__main__:Writing log message number 5575 to test rotation.
# INFO:__main__:Writing log message number 5576 to test rotation.
# INFO:__main__:Writing log message number 5577 to test rotation.
# INFO:__main__:Writing log message number 5578 to test rotation.
# INFO:__main__:Writing log message number 5579 to test rotation.
# INFO:__main__:Writing log message number 5580 to test rotation.
# INFO:__main__:Writing log message number 5581 to test rotation.
# INFO:__main__:Writing log message number 5582 to test rotation.
# INFO:__main__:Writing log message number 5583 to test rotation.
# INFO:__main__:Writing log message number 5584 to test rotation.
# INFO:__main__:Writing log message number 5585 to test rotation.
# INFO:__main__:Writing log message number 5586 to test rotation.
# INFO:__main__:Writing log message number 5587 to test rotation.
# INFO:__main__:Writing log message number 5588 to test rotation.
# INFO:__main__:Writing log message number 5589 to test rotation.
# INFO:__main__:Writing log message number 5590 to test rotation.
# INFO:__main__:Writing log message number 5591 to test rotation.
# INFO:__main__:Writing log message number 5592 to test rotation.
# INFO:__main__:Writing log message number 5593 to test rotation.
# INFO:__main__:Writing log message number 5594 to test rotation.
# INFO:__main__:Writing log message number 5595 to test rotation.
# INFO:__main__:Writing log message number 5596 to test rotation.
# INFO:__main__:Writing log message number 5597 to test rotation.
# INFO:__main__:Writing log message number 5598 to test rotation.
# INFO:__main__:Writing log message number 5599 to test rotation.
# INFO:__main__:Writing log message number 5600 to test rotation.
# INFO:__main__:Writing log message number 5601 to test rotation.
# INFO:__main__:Writing log message number 5602 to test rotation.
# INFO:__main__:Writing log message number 5603 to test rotation.
# INFO:__main__:Writing log message number 5604 to test rotation.
# INFO:__main__:Writing log message number 5605 to test rotation.
# INFO:__main__:Writing log message number 5606 to test rotation.
# INFO:__main__:Writing log message number 5607 to test rotation.
# INFO:__main__:Writing log message number 5608 to test rotation.
# INFO:__main__:Writing log message number 5609 to test rotation.
# INFO:__main__:Writing log message number 5610 to test rotation.
# INFO:__main__:Writing log message number 5611 to test rotation.
# INFO:__main__:Writing log message number 5612 to test rotation.
# INFO:__main__:Writing log message number 5613 to test rotation.
# INFO:__main__:Writing log message number 5614 to test rotation.
# INFO:__main__:Writing log message number 5615 to test rotation.
# INFO:__main__:Writing log message number 5616 to test rotation.
# INFO:__main__:Writing log message number 5617 to test rotation.
# INFO:__main__:Writing log message number 5618 to test rotation.
# INFO:__main__:Writing log message number 5619 to test rotation.
# INFO:__main__:Writing log message number 5620 to test rotation.
# INFO:__main__:Writing log message number 5621 to test rotation.
# INFO:__main__:Writing log message number 5622 to test rotation.
# INFO:__main__:Writing log message number 5623 to test rotation.
# INFO:__main__:Writing log message number 5624 to test rotation.
# INFO:__main__:Writing log message number 5625 to test rotation.
# INFO:__main__:Writing log message number 5626 to test rotation.
# INFO:__main__:Writing log message number 5627 to test rotation.
# INFO:__main__:Writing log message number 5628 to test rotation.
# INFO:__main__:Writing log message number 5629 to test rotation.
# INFO:__main__:Writing log message number 5630 to test rotation.
# INFO:__main__:Writing log message number 5631 to test rotation.
# INFO:__main__:Writing log message number 5632 to test rotation.
# INFO:__main__:Writing log message number 5633 to test rotation.
# INFO:__main__:Writing log message number 5634 to test rotation.
# INFO:__main__:Writing log message number 5635 to test rotation.
# INFO:__main__:Writing log message number 5636 to test rotation.
# INFO:__main__:Writing log message number 5637 to test rotation.
# INFO:__main__:Writing log message number 5638 to test rotation.
# INFO:__main__:Writing log message number 5639 to test rotation.
# INFO:__main__:Writing log message number 5640 to test rotation.
# INFO:__main__:Writing log message number 5641 to test rotation.
# INFO:__main__:Writing log message number 5642 to test rotation.
# INFO:__main__:Writing log message number 5643 to test rotation.
# INFO:__main__:Writing log message number 5644 to test rotation.
# INFO:__main__:Writing log message number 5645 to test rotation.
# INFO:__main__:Writing log message number 5646 to test rotation.
# INFO:__main__:Writing log message number 5647 to test rotation.
# INFO:__main__:Writing log message number 5648 to test rotation.
# INFO:__main__:Writing log message number 5649 to test rotation.
# INFO:__main__:Writing log message number 5650 to test rotation.
# INFO:__main__:Writing log message number 5651 to test rotation.
# INFO:__main__:Writing log message number 5652 to test rotation.
# INFO:__main__:Writing log message number 5653 to test rotation.
# INFO:__main__:Writing log message number 5654 to test rotation.
# INFO:__main__:Writing log message number 5655 to test rotation.
# INFO:__main__:Writing log message number 5656 to test rotation.
# INFO:__main__:Writing log message number 5657 to test rotation.
# INFO:__main__:Writing log message number 5658 to test rotation.
# INFO:__main__:Writing log message number 5659 to test rotation.
# INFO:__main__:Writing log message number 5660 to test rotation.
# INFO:__main__:Writing log message number 5661 to test rotation.
# INFO:__main__:Writing log message number 5662 to test rotation.
# INFO:__main__:Writing log message number 5663 to test rotation.
# INFO:__main__:Writing log message number 5664 to test rotation.
# INFO:__main__:Writing log message number 5665 to test rotation.
# INFO:__main__:Writing log message number 5666 to test rotation.
# INFO:__main__:Writing log message number 5667 to test rotation.
# INFO:__main__:Writing log message number 5668 to test rotation.
# INFO:__main__:Writing log message number 5669 to test rotation.
# INFO:__main__:Writing log message number 5670 to test rotation.
# INFO:__main__:Writing log message number 5671 to test rotation.
# INFO:__main__:Writing log message number 5672 to test rotation.
# INFO:__main__:Writing log message number 5673 to test rotation.
# INFO:__main__:Writing log message number 5674 to test rotation.
# INFO:__main__:Writing log message number 5675 to test rotation.
# INFO:__main__:Writing log message number 5676 to test rotation.
# INFO:__main__:Writing log message number 5677 to test rotation.
# INFO:__main__:Writing log message number 5678 to test rotation.
# INFO:__main__:Writing log message number 5679 to test rotation.
# INFO:__main__:Writing log message number 5680 to test rotation.
# INFO:__main__:Writing log message number 5681 to test rotation.
# INFO:__main__:Writing log message number 5682 to test rotation.
# INFO:__main__:Writing log message number 5683 to test rotation.
# INFO:__main__:Writing log message number 5684 to test rotation.
# INFO:__main__:Writing log message number 5685 to test rotation.
# INFO:__main__:Writing log message number 5686 to test rotation.
# INFO:__main__:Writing log message number 5687 to test rotation.
# INFO:__main__:Writing log message number 5688 to test rotation.
# INFO:__main__:Writing log message number 5689 to test rotation.
# INFO:__main__:Writing log message number 5690 to test rotation.
# INFO:__main__:Writing log message number 5691 to test rotation.
# INFO:__main__:Writing log message number 5692 to test rotation.
# INFO:__main__:Writing log message number 5693 to test rotation.
# INFO:__main__:Writing log message number 5694 to test rotation.
# INFO:__main__:Writing log message number 5695 to test rotation.
# INFO:__main__:Writing log message number 5696 to test rotation.
# INFO:__main__:Writing log message number 5697 to test rotation.
# INFO:__main__:Writing log message number 5698 to test rotation.
# INFO:__main__:Writing log message number 5699 to test rotation.
# INFO:__main__:Writing log message number 5700 to test rotation.
# INFO:__main__:Writing log message number 5701 to test rotation.
# INFO:__main__:Writing log message number 5702 to test rotation.
# INFO:__main__:Writing log message number 5703 to test rotation.
# INFO:__main__:Writing log message number 5704 to test rotation.
# INFO:__main__:Writing log message number 5705 to test rotation.
# INFO:__main__:Writing log message number 5706 to test rotation.
# INFO:__main__:Writing log message number 5707 to test rotation.
# INFO:__main__:Writing log message number 5708 to test rotation.
# INFO:__main__:Writing log message number 5709 to test rotation.
# INFO:__main__:Writing log message number 5710 to test rotation.
# INFO:__main__:Writing log message number 5711 to test rotation.
# INFO:__main__:Writing log message number 5712 to test rotation.
# INFO:__main__:Writing log message number 5713 to test rotation.
# INFO:__main__:Writing log message number 5714 to test rotation.
# INFO:__main__:Writing log message number 5715 to test rotation.
# INFO:__main__:Writing log message number 5716 to test rotation.
# INFO:__main__:Writing log message number 5717 to test rotation.
# INFO:__main__:Writing log message number 5718 to test rotation.
# INFO:__main__:Writing log message number 5719 to test rotation.
# INFO:__main__:Writing log message number 5720 to test rotation.
# INFO:__main__:Writing log message number 5721 to test rotation.
# INFO:__main__:Writing log message number 5722 to test rotation.
# INFO:__main__:Writing log message number 5723 to test rotation.
# INFO:__main__:Writing log message number 5724 to test rotation.
# INFO:__main__:Writing log message number 5725 to test rotation.
# INFO:__main__:Writing log message number 5726 to test rotation.
# INFO:__main__:Writing log message number 5727 to test rotation.
# INFO:__main__:Writing log message number 5728 to test rotation.
# INFO:__main__:Writing log message number 5729 to test rotation.
# INFO:__main__:Writing log message number 5730 to test rotation.
# INFO:__main__:Writing log message number 5731 to test rotation.
# INFO:__main__:Writing log message number 5732 to test rotation.
# INFO:__main__:Writing log message number 5733 to test rotation.
# INFO:__main__:Writing log message number 5734 to test rotation.
# INFO:__main__:Writing log message number 5735 to test rotation.
# INFO:__main__:Writing log message number 5736 to test rotation.
# INFO:__main__:Writing log message number 5737 to test rotation.
# INFO:__main__:Writing log message number 5738 to test rotation.
# INFO:__main__:Writing log message number 5739 to test rotation.
# INFO:__main__:Writing log message number 5740 to test rotation.
# INFO:__main__:Writing log message number 5741 to test rotation.
# INFO:__main__:Writing log message number 5742 to test rotation.
# INFO:__main__:Writing log message number 5743 to test rotation.
# INFO:__main__:Writing log message number 5744 to test rotation.
# INFO:__main__:Writing log message number 5745 to test rotation.
# INFO:__main__:Writing log message number 5746 to test rotation.
# INFO:__main__:Writing log message number 5747 to test rotation.
# INFO:__main__:Writing log message number 5748 to test rotation.
# INFO:__main__:Writing log message number 5749 to test rotation.
# INFO:__main__:Writing log message number 5750 to test rotation.
# ...
# 2025-07-12 15:29:33,021 - __main__ - INFO - Writing log message number 9832 to test rotation.
# 2025-07-12 15:29:33,022 - __main__ - INFO - Writing log message number 9833 to test rotation.
# 2025-07-12 15:29:33,023 - __main__ - INFO - Writing log message number 9834 to test rotation.
# 2025-07-12 15:29:33,023 - __main__ - INFO - Writing log message number 9835 to test rotation.
# 2025-07-12 15:29:33,024 - __main__ - INFO - Writing log message number 9836 to test rotation.
# 2025-07-12 15:29:33,024 - __main__ - INFO - Writing log message number 9837 to test rotation.
# 2025-07-12 15:29:33,025 - __main__ - INFO - Writing log message number 9838 to test rotation.
# 2025-07-12 15:29:33,025 - __main__ - INFO - Writing log message number 9839 to test rotation.
# 2025-07-12 15:29:33,026 - __main__ - INFO - Writing log message number 9840 to test rotation.
# 2025-07-12 15:29:33,026 - __main__ - INFO - Writing log message number 9841 to test rotation.
# 2025-07-12 15:29:33,027 - __main__ - INFO - Writing log message number 9842 to test rotation.
# 2025-07-12 15:29:33,027 - __main__ - INFO - Writing log message number 9843 to test rotation.
# 2025-07-12 15:29:33,028 - __main__ - INFO - Writing log message number 9844 to test rotation.
# 2025-07-12 15:29:33,028 - __main__ - INFO - Writing log message number 9845 to test rotation.
# 2025-07-12 15:29:33,029 - __main__ - INFO - Writing log message number 9846 to test rotation.
# 2025-07-12 15:29:33,029 - __main__ - INFO - Writing log message number 9847 to test rotation.
# 2025-07-12 15:29:33,030 - __main__ - INFO - Writing log message number 9848 to test rotation.
# 2025-07-12 15:29:33,030 - __main__ - INFO - Writing log message number 9849 to test rotation.
# 2025-07-12 15:29:33,031 - __main__ - INFO - Writing log message number 9850 to test rotation.
# 2025-07-12 15:29:33,032 - __main__ - INFO - Writing log message number 9851 to test rotation.
# 2025-07-12 15:29:33,032 - __main__ - INFO - Writing log message number 9852 to test rotation.
# 2025-07-12 15:29:33,033 - __main__ - INFO - Writing log message number 9853 to test rotation.
# 2025-07-12 15:29:33,033 - __main__ - INFO - Writing log message number 9854 to test rotation.
# 2025-07-12 15:29:33,034 - __main__ - INFO - Writing log message number 9855 to test rotation.
# 2025-07-12 15:29:33,035 - __main__ - INFO - Writing log message number 9856 to test rotation.
# 2025-07-12 15:29:33,035 - __main__ - INFO - Writing log message number 9857 to test rotation.
# 2025-07-12 15:29:33,036 - __main__ - INFO - Writing log message number 9858 to test rotation.
# 2025-07-12 15:29:33,036 - __main__ - INFO - Writing log message number 9859 to test rotation.
# 2025-07-12 15:29:33,037 - __main__ - INFO - Writing log message number 9860 to test rotation.
# 2025-07-12 15:29:33,038 - __main__ - INFO - Writing log message number 9861 to test rotation.
# 2025-07-12 15:29:33,038 - __main__ - INFO - Writing log message number 9862 to test rotation.
# 2025-07-12 15:29:33,039 - __main__ - INFO - Writing log message number 9863 to test rotation.
# 2025-07-12 15:29:33,039 - __main__ - INFO - Writing log message number 9864 to test rotation.
# 2025-07-12 15:29:33,040 - __main__ - INFO - Writing log message number 9865 to test rotation.
# 2025-07-12 15:29:33,040 - __main__ - INFO - Writing log message number 9866 to test rotation.
# 2025-07-12 15:29:33,041 - __main__ - INFO - Writing log message number 9867 to test rotation.
# 2025-07-12 15:29:33,042 - __main__ - INFO - Writing log message number 9868 to test rotation.
# 2025-07-12 15:29:33,042 - __main__ - INFO - Writing log message number 9869 to test rotation.
# 2025-07-12 15:29:33,043 - __main__ - INFO - Writing log message number 9870 to test rotation.
# 2025-07-12 15:29:33,043 - __main__ - INFO - Writing log message number 9871 to test rotation.
# 2025-07-12 15:29:33,044 - __main__ - INFO - Writing log message number 9872 to test rotation.
# 2025-07-12 15:29:33,044 - __main__ - INFO - Writing log message number 9873 to test rotation.
# 2025-07-12 15:29:33,045 - __main__ - INFO - Writing log message number 9874 to test rotation.
# 2025-07-12 15:29:33,045 - __main__ - INFO - Writing log message number 9875 to test rotation.
# 2025-07-12 15:29:33,046 - __main__ - INFO - Writing log message number 9876 to test rotation.
# 2025-07-12 15:29:33,046 - __main__ - INFO - Writing log message number 9877 to test rotation.
# 2025-07-12 15:29:33,047 - __main__ - INFO - Writing log message number 9878 to test rotation.
# 2025-07-12 15:29:33,047 - __main__ - INFO - Writing log message number 9879 to test rotation.
# 2025-07-12 15:29:33,048 - __main__ - INFO - Writing log message number 9880 to test rotation.
# 2025-07-12 15:29:33,048 - __main__ - INFO - Writing log message number 9881 to test rotation.
# 2025-07-12 15:29:33,049 - __main__ - INFO - Writing log message number 9882 to test rotation.
# 2025-07-12 15:29:33,049 - __main__ - INFO - Writing log message number 9883 to test rotation.
# 2025-07-12 15:29:33,050 - __main__ - INFO - Writing log message number 9884 to test rotation.
# 2025-07-12 15:29:33,051 - __main__ - INFO - Writing log message number 9885 to test rotation.
# 2025-07-12 15:29:33,051 - __main__ - INFO - Writing log message number 9886 to test rotation.
# 2025-07-12 15:29:33,052 - __main__ - INFO - Writing log message number 9887 to test rotation.
# 2025-07-12 15:29:33,052 - __main__ - INFO - Writing log message number 9888 to test rotation.
# 2025-07-12 15:29:33,053 - __main__ - INFO - Writing log message number 9889 to test rotation.
# 2025-07-12 15:29:33,054 - __main__ - INFO - Writing log message number 9890 to test rotation.
# 2025-07-12 15:29:33,054 - __main__ - INFO - Writing log message number 9891 to test rotation.
# 2025-07-12 15:29:33,055 - __main__ - INFO - Writing log message number 9892 to test rotation.
# 2025-07-12 15:29:33,055 - __main__ - INFO - Writing log message number 9893 to test rotation.
# 2025-07-12 15:29:33,056 - __main__ - INFO - Writing log message number 9894 to test rotation.
# 2025-07-12 15:29:33,056 - __main__ - INFO - Writing log message number 9895 to test rotation.
# 2025-07-12 15:29:33,057 - __main__ - INFO - Writing log message number 9896 to test rotation.
# 2025-07-12 15:29:33,058 - __main__ - INFO - Writing log message number 9897 to test rotation.
# 2025-07-12 15:29:33,058 - __main__ - INFO - Writing log message number 9898 to test rotation.
# 2025-07-12 15:29:33,059 - __main__ - INFO - Writing log message number 9899 to test rotation.
# 2025-07-12 15:29:33,059 - __main__ - INFO - Writing log message number 9900 to test rotation.
# 2025-07-12 15:29:33,060 - __main__ - INFO - Writing log message number 9901 to test rotation.
# 2025-07-12 15:29:33,061 - __main__ - INFO - Writing log message number 9902 to test rotation.
# 2025-07-12 15:29:33,063 - __main__ - INFO - Writing log message number 9903 to test rotation.
# 2025-07-12 15:29:33,064 - __main__ - INFO - Writing log message number 9904 to test rotation.
# 2025-07-12 15:29:33,064 - __main__ - INFO - Writing log message number 9905 to test rotation.
# 2025-07-12 15:29:33,065 - __main__ - INFO - Writing log message number 9906 to test rotation.
# 2025-07-12 15:29:33,066 - __main__ - INFO - Writing log message number 9907 to test rotation.
# 2025-07-12 15:29:33,066 - __main__ - INFO - Writing log message number 9908 to test rotation.
# 2025-07-12 15:29:33,067 - __main__ - INFO - Writing log message number 9909 to test rotation.
# 2025-07-12 15:29:33,069 - __main__ - INFO - Writing log message number 9910 to test rotation.
# 2025-07-12 15:29:33,069 - __main__ - INFO - Writing log message number 9911 to test rotation.
# 2025-07-12 15:29:33,070 - __main__ - INFO - Writing log message number 9912 to test rotation.
# 2025-07-12 15:29:33,071 - __main__ - INFO - Writing log message number 9913 to test rotation.
# 2025-07-12 15:29:33,071 - __main__ - INFO - Writing log message number 9914 to test rotation.
# 2025-07-12 15:29:33,072 - __main__ - INFO - Writing log message number 9915 to test rotation.
# 2025-07-12 15:29:33,072 - __main__ - INFO - Writing log message number 9916 to test rotation.
# 2025-07-12 15:29:33,073 - __main__ - INFO - Writing log message number 9917 to test rotation.
# 2025-07-12 15:29:33,073 - __main__ - INFO - Writing log message number 9918 to test rotation.
# 2025-07-12 15:29:33,074 - __main__ - INFO - Writing log message number 9919 to test rotation.
# 2025-07-12 15:29:33,075 - __main__ - INFO - Writing log message number 9920 to test rotation.
# 2025-07-12 15:29:33,075 - __main__ - INFO - Writing log message number 9921 to test rotation.
# 2025-07-12 15:29:33,076 - __main__ - INFO - Writing log message number 9922 to test rotation.
# 2025-07-12 15:29:33,076 - __main__ - INFO - Writing log message number 9923 to test rotation.
# 2025-07-12 15:29:33,077 - __main__ - INFO - Writing log message number 9924 to test rotation.
# 2025-07-12 15:29:33,077 - __main__ - INFO - Writing log message number 9925 to test rotation.
# 2025-07-12 15:29:33,078 - __main__ - INFO - Writing log message number 9926 to test rotation.
# 2025-07-12 15:29:33,082 - __main__ - INFO - Writing log message number 9927 to test rotation.
# 2025-07-12 15:29:33,082 - __main__ - INFO - Writing log message number 9928 to test rotation.
# 2025-07-12 15:29:33,083 - __main__ - INFO - Writing log message number 9929 to test rotation.
# 2025-07-12 15:29:33,083 - __main__ - INFO - Writing log message number 9930 to test rotation.
# 2025-07-12 15:29:33,084 - __main__ - INFO - Writing log message number 9931 to test rotation.
# 2025-07-12 15:29:33,085 - __main__ - INFO - Writing log message number 9932 to test rotation.
# 2025-07-12 15:29:33,085 - __main__ - INFO - Writing log message number 9933 to test rotation.
# 2025-07-12 15:29:33,086 - __main__ - INFO - Writing log message number 9934 to test rotation.
# 2025-07-12 15:29:33,086 - __main__ - INFO - Writing log message number 9935 to test rotation.
# 2025-07-12 15:29:33,087 - __main__ - INFO - Writing log message number 9936 to test rotation.
# 2025-07-12 15:29:33,087 - __main__ - INFO - Writing log message number 9937 to test rotation.
# 2025-07-12 15:29:33,088 - __main__ - INFO - Writing log message number 9938 to test rotation.
# 2025-07-12 15:29:33,089 - __main__ - INFO - Writing log message number 9939 to test rotation.
# 2025-07-12 15:29:33,092 - __main__ - INFO - Writing log message number 9940 to test rotation.
# 2025-07-12 15:29:33,092 - __main__ - INFO - Writing log message number 9941 to test rotation.
# 2025-07-12 15:29:33,093 - __main__ - INFO - Writing log message number 9942 to test rotation.
# 2025-07-12 15:29:33,094 - __main__ - INFO - Writing log message number 9943 to test rotation.
# 2025-07-12 15:29:33,094 - __main__ - INFO - Writing log message number 9944 to test rotation.
# 2025-07-12 15:29:33,095 - __main__ - INFO - Writing log message number 9945 to test rotation.
# 2025-07-12 15:29:33,095 - __main__ - INFO - Writing log message number 9946 to test rotation.
# 2025-07-12 15:29:33,096 - __main__ - INFO - Writing log message number 9947 to test rotation.
# 2025-07-12 15:29:33,097 - __main__ - INFO - Writing log message number 9948 to test rotation.
# 2025-07-12 15:29:33,097 - __main__ - INFO - Writing log message number 9949 to test rotation.
# 2025-07-12 15:29:33,100 - __main__ - INFO - Writing log message number 9950 to test rotation.
# 2025-07-12 15:29:33,101 - __main__ - INFO - Writing log message number 9951 to test rotation.
# 2025-07-12 15:29:33,102 - __main__ - INFO - Writing log message number 9952 to test rotation.
# 2025-07-12 15:29:33,102 - __main__ - INFO - Writing log message number 9953 to test rotation.
# 2025-07-12 15:29:33,103 - __main__ - INFO - Writing log message number 9954 to test rotation.
# 2025-07-12 15:29:33,103 - __main__ - INFO - Writing log message number 9955 to test rotation.
# 2025-07-12 15:29:33,104 - __main__ - INFO - Writing log message number 9956 to test rotation.
# 2025-07-12 15:29:33,104 - __main__ - INFO - Writing log message number 9957 to test rotation.
# 2025-07-12 15:29:33,105 - __main__ - INFO - Writing log message number 9958 to test rotation.
# 2025-07-12 15:29:33,106 - __main__ - INFO - Writing log message number 9959 to test rotation.
# 2025-07-12 15:29:33,106 - __main__ - INFO - Writing log message number 9960 to test rotation.
# 2025-07-12 15:29:33,107 - __main__ - INFO - Writing log message number 9961 to test rotation.
# 2025-07-12 15:29:33,107 - __main__ - INFO - Writing log message number 9962 to test rotation.
# 2025-07-12 15:29:33,108 - __main__ - INFO - Writing log message number 9963 to test rotation.
# 2025-07-12 15:29:33,108 - __main__ - INFO - Writing log message number 9964 to test rotation.
# 2025-07-12 15:29:33,109 - __main__ - INFO - Writing log message number 9965 to test rotation.
# 2025-07-12 15:29:33,110 - __main__ - INFO - Writing log message number 9966 to test rotation.
# 2025-07-12 15:29:33,110 - __main__ - INFO - Writing log message number 9967 to test rotation.
# 2025-07-12 15:29:33,111 - __main__ - INFO - Writing log message number 9968 to test rotation.
# 2025-07-12 15:29:33,111 - __main__ - INFO - Writing log message number 9969 to test rotation.
# 2025-07-12 15:29:33,112 - __main__ - INFO - Writing log message number 9970 to test rotation.
# 2025-07-12 15:29:33,112 - __main__ - INFO - Writing log message number 9971 to test rotation.
# 2025-07-12 15:29:33,113 - __main__ - INFO - Writing log message number 9972 to test rotation.
# 2025-07-12 15:29:33,113 - __main__ - INFO - Writing log message number 9973 to test rotation.
# 2025-07-12 15:29:33,114 - __main__ - INFO - Writing log message number 9974 to test rotation.
# 2025-07-12 15:29:33,114 - __main__ - INFO - Writing log message number 9975 to test rotation.
# 2025-07-12 15:29:33,115 - __main__ - INFO - Writing log message number 9976 to test rotation.
# 2025-07-12 15:29:33,115 - __main__ - INFO - Writing log message number 9977 to test rotation.
# 2025-07-12 15:29:33,116 - __main__ - INFO - Writing log message number 9978 to test rotation.
# 2025-07-12 15:29:33,116 - __main__ - INFO - Writing log message number 9979 to test rotation.
# 2025-07-12 15:29:33,117 - __main__ - INFO - Writing log message number 9980 to test rotation.
# 2025-07-12 15:29:33,117 - __main__ - INFO - Writing log message number 9981 to test rotation.
# 2025-07-12 15:29:33,118 - __main__ - INFO - Writing log message number 9982 to test rotation.
# 2025-07-12 15:29:33,118 - __main__ - INFO - Writing log message number 9983 to test rotation.
# 2025-07-12 15:29:33,119 - __main__ - INFO - Writing log message number 9984 to test rotation.
# 2025-07-12 15:29:33,119 - __main__ - INFO - Writing log message number 9985 to test rotation.
# 2025-07-12 15:29:33,120 - __main__ - INFO - Writing log message number 9986 to test rotation.
# 2025-07-12 15:29:33,121 - __main__ - INFO - Writing log message number 9987 to test rotation.
# 2025-07-12 15:29:33,121 - __main__ - INFO - Writing log message number 9988 to test rotation.
# 2025-07-12 15:29:33,122 - __main__ - INFO - Writing log message number 9989 to test rotation.
# 2025-07-12 15:29:33,122 - __main__ - INFO - Writing log message number 9990 to test rotation.
# 2025-07-12 15:29:33,126 - __main__ - INFO - Writing log message number 9991 to test rotation.
# 2025-07-12 15:29:33,126 - __main__ - INFO - Writing log message number 9992 to test rotation.
# 2025-07-12 15:29:33,127 - __main__ - INFO - Writing log message number 9993 to test rotation.
# 2025-07-12 15:29:33,127 - __main__ - INFO - Writing log message number 9994 to test rotation.
# 2025-07-12 15:29:33,128 - __main__ - INFO - Writing log message number 9995 to test rotation.
# 2025-07-12 15:29:33,128 - __main__ - INFO - Writing log message number 9996 to test rotation.
# 2025-07-12 15:29:33,129 - __main__ - INFO - Writing log message number 9997 to test rotation.
# 2025-07-12 15:29:33,130 - __main__ - INFO - Writing log message number 9998 to test rotation.
# 2025-07-12 15:29:33,130 - __main__ - INFO - Writing log message number 9999 to test rotation.
# 2025-07-12 15:29:33,131 - __main__ - INFO - Writing log message number 10000 to test rotation.
# 2025-07-12 15:29:33,131 - __main__ - INFO - Application finished.

# %%
# prompt: &F Write a program that handles both IndexError and KeyError using a try-except blockF

def handle_errors(data, index):
  """
  Demonstrates handling IndexError and KeyError using a try-except block.

  Args:
    data: A list or a dictionary.
    index: An index for a list or a key for a dictionary.
  """
  try:
    if isinstance(data, list):
      # Attempt to access a list element by index
      value = data[index]
      print(f"Value at index {index}: {value}")
    elif isinstance(data, dict):
      # Attempt to access a dictionary value by key
      value = data[index]
      print(f"Value for key '{index}': {value}")
    else:
      print("Input data must be a list or a dictionary.")

  except IndexError:
    print(f"Error: Index '{index}' is out of range for the list.")
  except KeyError:
    print(f"Error: Key '{index}' was not found in the dictionary.")
  except Exception as e:
    print(f"An unexpected error occurred: {e}")

# Example usage with a list
my_list = [10, 20, 30]
handle_errors(my_list, 1) # Valid index
handle_errors(my_list, 5) # Invalid index (IndexError)

print("-" * 20)

# Example usage with a dictionary
my_dict = {"apple": 1, "banana": 2}
handle_errors(my_dict, "apple") # Valid key
handle_errors(my_dict, "cherry") # Invalid key (KeyError)

print("-" * 20)

# Example usage with invalid data type
handle_errors("hello", 0)

# %%
# prompt: F How would you open a file and read its contents using a context manager in Python

file_path = "filename.txt"  # Replace with the actual filename

try:
    # Use 'with' to ensure the file is closed automatically
    with open(file_path, 'r') as file:
        # Read the entire content of the file
        content = file.read()
        print("File content:")
        print(content)

except FileNotFoundError:
    print(f"Error: The file '{file_path}' was not found.")
except IOError as e:
    print(f"An input/output error occurred while reading the file: {e}")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# File content:
# Hello, this is a test string written to a file.
# This is the new line being appended.
# /usr/local/lib/python3.11/dist-packages/IPython/core/inputtransformer2.py:478: UserWarning: `make_tokens_by_line` received a list of lines which do not have lineending markers ('\n', '\r', '\r\n', '\x0b', '\x0c'), behavior will be unspecified
#   warnings.warn("`make_tokens_by_line` received a list of lines which do not have lineending markers ('\\n', '\\r', '\\r\\n', '\\x0b', '\\x0c'), behavior will be unspecified")

# %%
# prompt: &F Write a Python program that reads a file and prints the number of occurrences of a specific wordF

def count_word_occurrences(file_path, word):
  """
  Reads a file and counts the occurrences of a specific word (case-insensitive).

  Args:
    file_path (str): The path to the file.
    word (str): The word to count.

  Returns:
    int: The number of occurrences of the word in the file.
  """
  count = 0
  try:
    with open(file_path, 'r') as file:
      content = file.read()
      # Split the content into words and convert to lowercase for case-insensitive matching
      words = content.lower().split()
      # Convert the target word to lowercase
      target_word = word.lower()
      # Count occurrences
      for w in words:
        # You might want more sophisticated word boundary checks depending on needs
        if w == target_word:
          count += 1
  except FileNotFoundError:
    print(f"Error: The file '{file_path}' was not found.")
    return -1 # Indicate an error
  except Exception as e:
    print(f"An error occurred while reading the file: {e}")
    return -1 # Indicate an error
  return count

# Create a dummy file for demonstration based on the previous code
file_path_for_counting = "my_new_file.txt"
word_to_find = "python"

# Call the function and print the result
occurrences = count_word_occurrences(file_path_for_counting, word_to_find)

if occurrences != -1: # Check if the function executed without a file error
  print(f"The word '{word_to_find}' appears {occurrences} times in '{file_path_for_counting}'.")

# Example with a word that is likely to appear
word_to_find_python = "Python"
occurrences_python = count_word_occurrences(file_path_for_counting, word_to_find_python)
if occurrences_python != -1:
    print(f"The word '{word_to_find_python}' appears {occurrences_python} times in '{file_path_for_counting}'.")

# Example with a non-existent file
count_word_occurrences("non_existent_file_for_counting.txt", "test")
# Out:
# The word 'file' appears 1 times in 'my_new_file.txt'.
# The word 'occurrence' appears 0 times in 'my_new_file.txt'.
# Error: The file 'non_existent.txt' was not found.
# /usr/local/lib/python3.11/dist-packages/IPython/core/inputtransformer2.py:478: UserWarning: `make_tokens_by_line` received a list of lines which do not have lineending markers ('\n', '\r', '\r\n', '\x0b', '\x0c'), behavior will be unspecified
#   warnings.warn("`make_tokens_by_line` received a list of lines which do not have lineending markers ('\\n', '\\r', '\\r\\n', '\\x0b', '\\x0c'), behavior will be unspecified")
# -1

# %%
# prompt: F How can you check if a file is empty before attempting to read its contents

import os

def is_file_empty(file_path):
  """
  Checks if a file is empty.

  Args:
    file_path (str): The path to the file.

  Returns:
    bool: True if the file is empty or does not exist, False otherwise.
          Returns True also if the file does not exist to prevent reading.
  """
  if not os.path.exists(file_path):
    print(f"Warning: File '{file_path}' does not exist.")
    return True  # Consider a non-existent file as "empty" for reading purposes
  return os.path.getsize(file_path) == 0

# Example Usage:

# Create a dummy file for demonstration
dummy_file_name = "check_empty_file.txt"
with open(dummy_file_name, "w") as f:
    f.write("This file has content.")

# Create an empty file for demonstration
empty_file_name = "check_empty_file_empty.txt"
with open(empty_file_name, "w") as f:
    pass # Creates an empty file

# Check the dummy file
if is_file_empty(dummy_file_name):
  print(f"'{dummy_file_name}' is empty.")
else:
  print(f"'{dummy_file_name}' is not empty. Attempting to read...")
  try:
    with open(dummy_file_name, 'r') as f:
      print(f.read())
  except Exception as e:
    print(f"An error occurred while reading '{dummy_file_name}': {e}")

print("-" * 20)

# Check the empty file
if is_file_empty(empty_file_name):
  print(f"'{empty_file_name}' is empty.")
else:
  print(f"'{empty_file_name}' is not empty. Attempting to read...")
  try:
    with open(empty_file_name, 'r') as f:
      print(f.read())
  except Exception as e:
    print(f"An error occurred while reading '{empty_file_name}': {e}")

print("-" * 20)

# Check a non-existent file
non_existent_file = "non_existent_file_check.txt"
if is_file_empty(non_existent_file):
  print(f"'{non_existent_file}' is empty or does not exist.")
else:
  print(f"'{non_existent_file}' is not empty. Attempting to read...")
  try:
    with open(non_existent_file, 'r') as f:
      print(f.read())
  except Exception as e:
    print(f"An error occurred while reading '{non_existent_file}': {e}")


# Clean up the dummy files
os.remove(dummy_file_name)
os.remove(empty_file_name)
# Out:
# 'check_empty_file.txt' is not empty. Attempting to read...
# This file has content.
# --------------------
# 'check_empty_file_empty.txt' is empty.
# --------------------
# Warning: File 'non_existent_file_check.txt' does not exist.
# 'non_existent_file_check.txt' is empty or does not exist.
# /usr/local/lib/python3.11/dist-packages/IPython/core/inputtransformer2.py:478: UserWarning: `make_tokens_by_line` received a list of lines which do not have lineending markers ('\n', '\r', '\r\n', '\x0b', '\x0c'), behavior will be unspecified
#   warnings.warn("`make_tokens_by_line` received a list of lines which do not have lineending markers ('\\n', '\\r', '\\r\\n', '\\x0b', '\\x0c'), behavior will be unspecified")

# %%
# prompt: =F Write a Python program that writes to a log file when an error occurs during file handling.

# Configure logging to write error messages to a file
logging.basicConfig(filename='file_errors.log', level=logging.ERROR,
                    format='%(asctime)s:%(levelname)s:%(message)s')

def read_file_safely(file_path):
  """
  Reads the content of a file and logs an error if FileNotFoundError occurs.

  Args:
    file_path (str): The path to the file to read.
  """
  try:
    with open(file_path, 'r') as f:
      content = f.read()
      print(f"Successfully read content from '{file_path}':")
      print(content)
  except FileNotFoundError:
    logging.error(f"File not found: {file_path}")
    print(f"Error: The file '{file_path}' was not found. An error has been logged.")
  except Exception as e:
    logging.error(f"An unexpected error occurred while reading {file_path}: {e}")
    print(f"An unexpected error occurred: {e}. Details logged to file_errors.log")

# Example usage:
existing_file = "my_new_file.txt" # Assuming this file was created earlier
non_existent_file = "this_file_does_not_exist.txt"

print(f"Attempting to read existing file: {existing_file}")
read_file_safely(existing_file)

print("\n" + "="*30 + "\n")

print(f"Attempting to read non-existent file: {non_existent_file}")
read_file_safely(non_existent_file)

# You can check the contents of 'file_errors.log' to see the logged error message
# To view the log file in Colab:
# !cat file_errors.log
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/inputtransformer2.py:478: UserWarning: `make_tokens_by_line` received a list of lines which do not have lineending markers ('\n', '\r', '\r\n', '\x0b', '\x0c'), behavior will be unspecified
#   warnings.warn("`make_tokens_by_line` received a list of lines which do not have lineending markers ('\\n', '\\r', '\\r\\n', '\\x0b', '\\x0c'), behavior will be unspecified")
# ERROR:root:File not found: this_file_does_not_exist.txt
# Attempting to read existing file: my_new_file.txt
# Successfully read content from 'my_new_file.txt':
# Hello, this is a test string written to a file.
# This is the new line being appended.
#
# ==============================
#
# Attempting to read non-existent file: this_file_does_not_exist.txt
# Error: The file 'this_file_does_not_exist.txt' was not found. An error has been logged.
# cat: file_errors.log: No such file or directory
